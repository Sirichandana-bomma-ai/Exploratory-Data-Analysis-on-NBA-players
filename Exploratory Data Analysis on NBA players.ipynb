# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the dataset
data = pd.read_csv('player_data.csv')

# %%
data.head()
# Out:
#              Name  Age Team  Games  Rebounds  Assists  Steals  Blocks  \
# 0    James Harden   25  HOU     81       459      565     154      60
# 1      Chris Paul   29  LAC     82       376      838     156      15
# 2   Stephen Curry   26  GSW     80       341      619     163      16
# 3   Anthony Davis   21  NOP     68       696      149     100     200
# 4  DeAndre Jordan   26  LAC     82      1226       61      81     183
#
#    Turnovers  Points
# 0        321    2217
# 1        190    1564
# 2        249    1900
# 3         95    1656
# 4        109     946

# %% [markdown]
# # Exploratory Data Analysis

# %%
# checking for duplicates 

duplicates = data[data.duplicated()]

if duplicates.empty:
    print('No duplicates found.')
else:
    print('Duplicates found:')
    print(duplicates)
# Out:
# No duplicates found.

# %%
# check for null values
print(data.isnull().sum())
# Out:
# Name         0
# Age          0
# Team         0
# Games        0
# Rebounds     0
# Assists      0
# Steals       0
# Blocks       0
# Turnovers    0
# Points       0
# dtype: int64

# %%
data = data.dropna()

# %%
# Statistical Summary
data.describe()
# Out:
#               Age       Games     Rebounds     Assists      Steals  \
# count  492.000000  492.000000   492.000000  492.000000  492.000000
# mean    26.536585   52.806911   216.471545  110.166667   38.680894
# std      4.193473   24.344049   192.089723  125.922489   33.413136
# min     19.000000    1.000000     0.000000    0.000000    0.000000
# 25%     23.000000   33.000000    68.750000   23.750000   12.000000
# 50%     26.000000   61.000000   176.000000   69.500000   32.000000
# 75%     29.000000   74.000000   314.250000  150.250000   54.500000
# max     38.000000   83.000000  1226.000000  838.000000  163.000000
#
#            Blocks   Turnovers       Points
# count  492.000000  492.000000   492.000000
# mean    23.977642   68.546748   500.071138
# std     31.635486   58.525882   422.431191
# min      0.000000    0.000000     0.000000
# 25%      4.750000   22.000000   141.000000
# 50%     14.000000   55.500000   420.500000
# 75%     29.250000  100.000000   772.000000
# max    200.000000  321.000000  2217.000000

# %% [markdown]
# # Distribution of Data

# %%
data.hist(figsize=(10, 10))
plt.show()

# %%
# Plotting a boxplot for each column in the dataset
data.boxplot(figsize=(8,8))
plt.show()

# %% [markdown]
# # Correlation Analysis

# %%
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Performance Analysis

# %%
sns.pairplot(data, x_vars = ['Games', 'Rebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers' ], 
             y_vars=['Points'], height = 5, aspect = 0.7, kind = 'reg')
plt.show()
